# %%
import pandas as pd

# %%
pd.options.mode.chained_assignment = None  # default='warn'

# %%
survey_df = pd.read_csv("survey.csv", low_memory=False)
survey_df.head()
# Out:
#        cps19_StartDate        cps19_EndDate   cps19_ResponseId  \
# 0  2019-09-13 08:09:44  2019-09-13 08:36:19  R_1OpYXEFGzHRUpjM
# 1  2019-09-13 08:39:09  2019-09-13 08:57:06  R_2qdrL3J618rxYW0
# 2  2019-09-13 10:01:19  2019-09-13 10:27:29  R_USWDAPcQEQiMmNb
# 3  2019-09-13 10:05:37  2019-09-13 10:50:53  R_3IQaeDXy0tBzEry
# 4  2019-09-13 10:05:52  2019-09-13 10:32:53  R_27WeMQ1asip2cMD
#
#                                        cps19_consent cps19_citizenship  \
# 0  I consent to participate in this study. I have...  Canadian citizen
# 1  I consent to participate in this study. I have...  Canadian citizen
# 2  I consent to participate in this study. I have...  Canadian citizen
# 3  I consent to participate in this study. I have...  Canadian citizen
# 4  I consent to participate in this study. I have...  Canadian citizen
#
#    cps19_yob  cps19_yob_2001_age cps19_gender cps19_province  \
# 0       1989                 NaN      A woman         Quebec
# ...

# %%
columns = list(survey_df.columns)
columns
# Out:
# ['cps19_StartDate',
#  'cps19_EndDate',
#  'cps19_ResponseId',
#  'cps19_consent',
#  'cps19_citizenship',
#  'cps19_yob',
#  'cps19_yob_2001_age',
#  'cps19_gender',
#  'cps19_province',
#  'cps19_education',
#  'cps19_demsat',
#  'cps19_imp_iss',
#  'cps19_imp_iss_party',
#  'cps19_imp_iss_party_7_TEXT',
#  'cps19_imp_loc_iss',
#  'cps19_imp_loc_iss_p',
#  'cps19_imp_loc_iss_p_7_TEXT',
#  'cps19_interest_gen_1',
#  'cps19_interest_elxn_1',
#  'cps19_v_likely',
#  'cps19_v_likely_pr',
#  'cps19_votechoice',
#  'cps19_votechoice_7_TEXT',
#  'cps19_votechoice_pr',
#  'cps19_votechoice_pr_7_TEXT',
#  'cps19_vote_unlikely',
#  'cps19_vote_unlikely_7_TEXT',
#  'cps19_vote_unlike_pr',
#  'cps19_vote_unlike_pr_7_TEXT',
#  'cps19_v_advance',
#  'cps19_v_advance_7_TEXT',
#  'cps19_vote_lean',
#  'cps19_vote_lean_7_TEXT',
#  'cps19_vote_lean_pr',
#  'cps19_vote_lean_pr_7_TEXT',
#  'cps19_2nd_choice',
#  'cps19_2nd_choice_7_TEXT',
#  'cps19_2nd_choice_pr',
#  'cps19_2nd_choice_pr_7_TEXT',
# ...

# %%
cps_columns = []
for column in columns:
    if 'cps19' in column:
        cps_columns.append(column)

# %%
cps_df = survey_df[cps_columns]
cps_df.head()
# Out:
#        cps19_StartDate        cps19_EndDate   cps19_ResponseId  \
# 0  2019-09-13 08:09:44  2019-09-13 08:36:19  R_1OpYXEFGzHRUpjM
# 1  2019-09-13 08:39:09  2019-09-13 08:57:06  R_2qdrL3J618rxYW0
# 2  2019-09-13 10:01:19  2019-09-13 10:27:29  R_USWDAPcQEQiMmNb
# 3  2019-09-13 10:05:37  2019-09-13 10:50:53  R_3IQaeDXy0tBzEry
# 4  2019-09-13 10:05:52  2019-09-13 10:32:53  R_27WeMQ1asip2cMD
#
#                                        cps19_consent cps19_citizenship  \
# 0  I consent to participate in this study. I have...  Canadian citizen
# 1  I consent to participate in this study. I have...  Canadian citizen
# 2  I consent to participate in this study. I have...  Canadian citizen
# 3  I consent to participate in this study. I have...  Canadian citizen
# 4  I consent to participate in this study. I have...  Canadian citizen
#
#    cps19_yob  cps19_yob_2001_age cps19_gender cps19_province  \
# 0       1989                 NaN      A woman         Quebec
# ...

# %%
cps_df.drop(['cps19_StartDate', 'cps19_EndDate', 'cps19_consent', 'cps19_yob_2001_age', 'cps19_current_date_string', 'cps19_Q_Language', 'cps19_Q_TotalDuration', 'cps19_data_quality', 'cps19_panel', 'cps19_age', 'cps19_duplicates_flag', 'cps19_inattentive', 'cps19_weight_general_restricted'], axis=1, inplace=True)

# %%
cps_df.head()
# Out:
#     cps19_ResponseId cps19_citizenship  cps19_yob cps19_gender cps19_province  \
# 0  R_1OpYXEFGzHRUpjM  Canadian citizen       1989      A woman         Quebec
# 1  R_2qdrL3J618rxYW0  Canadian citizen       1998      A woman         Quebec
# 2  R_USWDAPcQEQiMmNb  Canadian citizen       2000      A woman        Ontario
# 3  R_3IQaeDXy0tBzEry  Canadian citizen       1998        A man        Ontario
# 4  R_27WeMQ1asip2cMD  Canadian citizen       2000      A woman        Ontario
#
#                     cps19_education                      cps19_demsat  \
# 0                   Master's degree                  Fairly satisfied
# 1                   Master's degree  Don't know/ Prefer not to answer
# 2                   Some university                  Fairly satisfied
# 3                   Some university                  Fairly satisfied
# 4  Completed secondary/ high school                  Fairly satisfied
#
#                       cps19_imp_iss               cps19_imp_iss_party  \
# ...

# %%
cps_df.drop(['cps19_current_date', 'cps19_weight_general_all'], axis=1, inplace=True)

# %%
cps_df.head()
# Out:
#     cps19_ResponseId cps19_citizenship  cps19_yob cps19_gender cps19_province  \
# 0  R_1OpYXEFGzHRUpjM  Canadian citizen       1989      A woman         Quebec
# 1  R_2qdrL3J618rxYW0  Canadian citizen       1998      A woman         Quebec
# 2  R_USWDAPcQEQiMmNb  Canadian citizen       2000      A woman        Ontario
# 3  R_3IQaeDXy0tBzEry  Canadian citizen       1998        A man        Ontario
# 4  R_27WeMQ1asip2cMD  Canadian citizen       2000      A woman        Ontario
#
#                     cps19_education                      cps19_demsat  \
# 0                   Master's degree                  Fairly satisfied
# 1                   Master's degree  Don't know/ Prefer not to answer
# 2                   Some university                  Fairly satisfied
# 3                   Some university                  Fairly satisfied
# 4  Completed secondary/ high school                  Fairly satisfied
#
#                       cps19_imp_iss               cps19_imp_iss_party  \
# ...

# %%
cps_df.drop(['cps19_imp_iss_party_7_TEXT'], axis=1, inplace=True)

# %%
demographics_df = cps_df[['cps19_ResponseId', 'cps19_citizenship', 'cps19_yob', 'cps19_gender', 'cps19_gender', 'cps19_education', 'cps19_income_cat', 'cps19_employment', 'cps19_sector', 'cps19_union', 'cps19_sexuality', 'cps19_marital', 'cps19_household', 'cps19_children']]
demographics_df.head(20)
# Out:
#      cps19_ResponseId   cps19_citizenship  cps19_yob cps19_gender  \
# 0   R_1OpYXEFGzHRUpjM    Canadian citizen       1989      A woman
# 1   R_2qdrL3J618rxYW0    Canadian citizen       1998      A woman
# 2   R_USWDAPcQEQiMmNb    Canadian citizen       2000      A woman
# 3   R_3IQaeDXy0tBzEry    Canadian citizen       1998        A man
# 4   R_27WeMQ1asip2cMD    Canadian citizen       2000      A woman
# 5   R_3LiGZcCWJEcWV4P    Canadian citizen       1999      A woman
# 6   R_1Iu8R1UlYzVMycz  Permanent resident       1998      A woman
# 7   R_2EcS26hqrcVYlab    Canadian citizen       1998      A woman
# 8   R_3yrt44wqQ1d4VRn    Canadian citizen       1998      A woman
# 9   R_10OBmXJyvn8feYQ    Canadian citizen       2000        A man
# 10  R_2e5nvu0UchQctgq    Canadian citizen       2000      A woman
# 11  R_2OJdv16hkRGnjOn    Canadian citizen       1998      A woman
# 12  R_3F5wpLvNlRtNQuK    Canadian citizen       1999        A man
# ...

# %%
cps_df[['cps19_property_1', 'cps19_property_2', 'cps19_property_3', 'cps19_property_4', 'cps19_property_5']].isnull().sum()
# Out:
# cps19_property_1    13023
# cps19_property_2    34452
# cps19_property_3    27205
# cps19_property_4    19893
# cps19_property_5    31834
# dtype: int64

# %%
cps_df.drop(['cps19_property_1', 'cps19_property_2', 'cps19_property_3', 'cps19_property_4', 'cps19_property_5'], axis=1, inplace=True)

# %%
cps_df.drop(['cps19_income_cat'], axis=1, inplace=True)

# %%
cps_df.head()
# Out:
#     cps19_ResponseId cps19_citizenship  cps19_yob cps19_gender cps19_province  \
# 0  R_1OpYXEFGzHRUpjM  Canadian citizen       1989      A woman         Quebec
# 1  R_2qdrL3J618rxYW0  Canadian citizen       1998      A woman         Quebec
# 2  R_USWDAPcQEQiMmNb  Canadian citizen       2000      A woman        Ontario
# 3  R_3IQaeDXy0tBzEry  Canadian citizen       1998        A man        Ontario
# 4  R_27WeMQ1asip2cMD  Canadian citizen       2000      A woman        Ontario
#
#                     cps19_education                      cps19_demsat  \
# 0                   Master's degree                  Fairly satisfied
# 1                   Master's degree  Don't know/ Prefer not to answer
# 2                   Some university                  Fairly satisfied
# 3                   Some university                  Fairly satisfied
# 4  Completed secondary/ high school                  Fairly satisfied
#
#                       cps19_imp_iss               cps19_imp_iss_party  \
# ...

# %%
cps_df['cps19_citizenship'].value_counts()
# Out:
# Canadian citizen      36480
# Permanent resident     1342
# Name: cps19_citizenship, dtype: int64

# %%
cps_df['cps19_pos_carbon'].isnull().sum()
# Out:
# 25273

# %%
cps_df['cps19_votechoice'].value_counts()
# Out:
# Liberal Party                       8949
# Conservative Party                  8713
# Don't know/ Prefer not to answer    4908
# ndp                                 4328
# Green Party                         2456
# Bloc Qu<e9>b<e9>cois                1404
# People's Party                       605
# Another party (please specify)       201
# Name: cps19_votechoice, dtype: int64

# %%
cps_df['cps19_votechoice'].isnull().sum()
# Out:
# 6258

# %%
vote_by_income = cps_df[['cps19_votechoice', 'cps19_income_number']]
vote_by_income
# Out:
#                        cps19_votechoice  cps19_income_number
# 0                           Green Party                  NaN
# 1      Don't know/ Prefer not to answer                  NaN
# 2                         Liberal Party                  NaN
# 3                    Conservative Party                  NaN
# 4      Don't know/ Prefer not to answer             56000.00
# ...                                 ...                  ...
# 37817                     Liberal Party                  NaN
# 37818                       Green Party             62000.00
# 37819                               NaN                  NaN
# 37820                               NaN             50000.00
# 37821                               NaN                  NaN
#
# [37822 rows x 2 columns]

# %%
vote_by_income = vote_by_income.dropna()

# %%
no_answer = vote_by_income[(vote_by_income['cps19_votechoice'] == "Don't know/ Prefer not to answer")].index

# %%
vote_by_income.drop(no_answer, inplace=True)

# %%
vote_by_income
# Out:
#            cps19_votechoice  cps19_income_number
# 13            Liberal Party             30000.00
# 14            Liberal Party             16000.00
# 20                      ndp             13000.00
# 21       Conservative Party             55000.00
# 22            Liberal Party           1000000.00
# ...                     ...                  ...
# 37810                   ndp             40000.00
# 37811  Bloc Qu<e9>b<e9>cois             99700.00
# 37815  Bloc Qu<e9>b<e9>cois            150000.00
# 37816                   ndp             37500.00
# 37818           Green Party             62000.00
#
# [19068 rows x 2 columns]

# %%
pref_by_income = vote_by_income.groupby(['cps19_votechoice']).mean()['cps19_income_number']
pref_by_income
# Out:
# cps19_votechoice
# Another party (please specify)          84054.17
# Bloc Qu<e9>b<e9>cois                    87296.73
# Conservative Party               160025873730.69
# Green Party                            108530.42
# Liberal Party                          240864.96
# People's Party                       21108732.63
# ndp                                     77893.85
# Name: cps19_income_number, dtype: float64

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
pref_by_income
# Out:
# cps19_votechoice
# Another party (please specify)          84054.17
# Bloc Qu<e9>b<e9>cois                    87296.73
# Conservative Party               160025873730.69
# Green Party                            108530.42
# Liberal Party                          240864.96
# People's Party                       21108732.63
# ndp                                     77893.85
# Name: cps19_income_number, dtype: float64

# %%
vote_by_income.describe()
# Out:
#        cps19_income_number
# count             19068.00
# mean        52444551060.14
# std       7241815033358.10
# min                   0.00
# 25%               45000.00
# 50%               75000.00
# 75%              110000.00
# max     999999999999999.00

# %%
b

# %%
vote_by_income.drop(outlier_income, inplace=True)

# %%
vote_by_income.describe()
# Out:
#        cps19_income_number
# count             19067.00
# mean             666052.07
# std            65010418.17
# min                   0.00
# 25%               45000.00
# 50%               75000.00
# 75%              110000.00
# max          8889898989.00

# %%
cps_df.head()
# Out:
#     cps19_ResponseId cps19_citizenship  cps19_yob cps19_gender cps19_province  \
# 0  R_1OpYXEFGzHRUpjM  Canadian citizen       1989      A woman         Quebec
# 1  R_2qdrL3J618rxYW0  Canadian citizen       1998      A woman         Quebec
# 2  R_USWDAPcQEQiMmNb  Canadian citizen       2000      A woman        Ontario
# 3  R_3IQaeDXy0tBzEry  Canadian citizen       1998        A man        Ontario
# 4  R_27WeMQ1asip2cMD  Canadian citizen       2000      A woman        Ontario
#
#                     cps19_education                      cps19_demsat  \
# 0                   Master's degree                  Fairly satisfied
# 1                   Master's degree  Don't know/ Prefer not to answer
# 2                   Some university                  Fairly satisfied
# 3                   Some university                  Fairly satisfied
# 4  Completed secondary/ high school                  Fairly satisfied
#
#                       cps19_imp_iss               cps19_imp_iss_party  \
# ...

# %%
cps_df.iloc[:, 0:10].head()
# Out:
#     cps19_ResponseId cps19_citizenship  cps19_yob cps19_gender cps19_province  \
# 0  R_1OpYXEFGzHRUpjM  Canadian citizen       1989      A woman         Quebec
# 1  R_2qdrL3J618rxYW0  Canadian citizen       1998      A woman         Quebec
# 2  R_USWDAPcQEQiMmNb  Canadian citizen       2000      A woman        Ontario
# 3  R_3IQaeDXy0tBzEry  Canadian citizen       1998        A man        Ontario
# 4  R_27WeMQ1asip2cMD  Canadian citizen       2000      A woman        Ontario
#
#                     cps19_education                      cps19_demsat  \
# 0                   Master's degree                  Fairly satisfied
# 1                   Master's degree  Don't know/ Prefer not to answer
# 2                   Some university                  Fairly satisfied
# 3                   Some university                  Fairly satisfied
# 4  Completed secondary/ high school                  Fairly satisfied
#
#                       cps19_imp_iss               cps19_imp_iss_party  \
# ...

# %%
cps_df.iloc[:, 0:10].isnull().sum()
# Out:
# cps19_ResponseId           0
# cps19_citizenship          0
# cps19_yob                  0
# cps19_gender               0
# cps19_province             0
# cps19_education            0
# cps19_demsat               0
# cps19_imp_iss           7438
# cps19_imp_iss_party     7422
# cps19_imp_loc_iss      24301
# dtype: int64

# %%
cps_df.drop(['cps19_imp_loc_iss'], axis=1, inplace=True)

# %%
cps_df.iloc[:, 10:20].head()
# Out:
#   cps19_imp_loc_iss_p_7_TEXT  cps19_interest_gen_1  cps19_interest_elxn_1  \
# 0                        NaN                  9.00                   9.00
# 1                        NaN                  6.00                   6.00
# 2                        NaN                  8.00                   8.00
# 3                        NaN                  8.00                   8.00
# 4                        NaN                  8.00                   6.00
#
#     cps19_v_likely cps19_v_likely_pr                  cps19_votechoice  \
# 0  Certain to vote               NaN                       Green Party
# 1  Certain to vote               NaN  Don't know/ Prefer not to answer
# 2  Certain to vote               NaN                     Liberal Party
# 3  Certain to vote               NaN                Conservative Party
# 4  Certain to vote               NaN  Don't know/ Prefer not to answer
#
#   cps19_votechoice_7_TEXT cps19_votechoice_pr cps19_votechoice_pr_7_TEXT  \
# ...

# %%
cps_df['cps19_vote_unlikely'].value_counts()
# Out:
# Don't know/ Prefer not to answer    328
# Liberal Party                       256
# Conservative Party                  241
# ndp                                 205
# Green Party                         175
# People's Party                       39
# Bloc Qu<e9>b<e9>cois                 38
# Another party (please specify)       21
# Name: cps19_vote_unlikely, dtype: int64

# %%
cps_df.drop(['cps19_vote_unlikely'], axis=1, inplace=True)

# %%
cps_df.drop(['cps19_imp_loc_iss_p_7_TEXT'], axis=1, inplace=True)

# %%
cps_df.drop(['cps19_v_likely_pr'], axis=1, inplace=True)

# %%
cps_df.drop(['cps19_votechoice_7_TEXT'], axis=1, inplace=True)

# %%
cps_df.drop(['cps19_votechoice_pr'], axis=1, inplace=True)

# %%
cps_df.drop(['cps19_votechoice_pr_7_TEXT'], axis=1, inplace=True)

# %%
cps_df.iloc[:, 10:20].head()
# Out:
#    cps19_interest_gen_1  cps19_interest_elxn_1   cps19_v_likely  \
# 0                  9.00                   9.00  Certain to vote
# 1                  6.00                   6.00  Certain to vote
# 2                  8.00                   8.00  Certain to vote
# 3                  8.00                   8.00  Certain to vote
# 4                  8.00                   6.00  Certain to vote
#
#                    cps19_votechoice cps19_vote_unlikely_7_TEXT  \
# 0                       Green Party                        NaN
# 1  Don't know/ Prefer not to answer                        NaN
# 2                     Liberal Party                        NaN
# 3                Conservative Party                        NaN
# 4  Don't know/ Prefer not to answer                        NaN
#
#   cps19_vote_unlike_pr  cps19_vote_unlike_pr_7_TEXT cps19_v_advance  \
# 0                  NaN                          NaN             NaN
# ...

# %%
cps_df.drop(['cps19_vote_unlikely_7_TEXT', 'cps19_vote_unlike_pr'], axis=1, inplace=True)

# %%
cps_df.drop(['cps19_v_advance_7_TEXT'], axis=1, inplace=True)

# %%
cps_df.drop(['cps19_vote_lean'], axis=1, inplace=True)

# %%
cps_df.drop(['cps19_vote_lean_7_TEXT'], axis=1, inplace=True)

# %%
cps_df.iloc[:, 10:20].head()
# Out:
#    cps19_interest_gen_1  cps19_interest_elxn_1   cps19_v_likely  \
# 0                  9.00                   9.00  Certain to vote
# 1                  6.00                   6.00  Certain to vote
# 2                  8.00                   8.00  Certain to vote
# 3                  8.00                   8.00  Certain to vote
# 4                  8.00                   6.00  Certain to vote
#
#                    cps19_votechoice  cps19_vote_unlike_pr_7_TEXT  \
# 0                       Green Party                          NaN
# 1  Don't know/ Prefer not to answer                          NaN
# 2                     Liberal Party                          NaN
# 3                Conservative Party                          NaN
# 4  Don't know/ Prefer not to answer                          NaN
#
#   cps19_v_advance cps19_vote_lean_pr  cps19_vote_lean_pr_7_TEXT  \
# 0             NaN                NaN                        NaN
# ...

# %%
cps_df.drop(['cps19_v_advance', 'cps19_vote_lean_pr', 'cps19_2nd_choice_7_TEXT', 'cps19_2nd_choice_pr', 'cps19_2nd_choice_pr_7_TEXT'], axis=1, inplace=True)

# %%
cps_df.iloc[:, 10:20].head()
# Out:
#    cps19_interest_gen_1  cps19_interest_elxn_1   cps19_v_likely  \
# 0                  9.00                   9.00  Certain to vote
# 1                  6.00                   6.00  Certain to vote
# 2                  8.00                   8.00  Certain to vote
# 3                  8.00                   8.00  Certain to vote
# 4                  8.00                   6.00  Certain to vote
#
#                    cps19_votechoice  cps19_vote_unlike_pr_7_TEXT  \
# 0                       Green Party                          NaN
# 1  Don't know/ Prefer not to answer                          NaN
# 2                     Liberal Party                          NaN
# 3                Conservative Party                          NaN
# 4  Don't know/ Prefer not to answer                          NaN
#
#    cps19_vote_lean_pr_7_TEXT                  cps19_2nd_choice  \
# 0                        NaN                     Liberal Party
# ...

# %%
cps_df.drop(['cps19_not_vote_for_1', 'cps19_not_vote_for_2', 'cps19_not_vote_for_3', 'cps19_not_vote_for_4', 'cps19_not_vote_for_5'], axis=1, inplace=True)

# %%
cps_df.iloc[:, 10:20].head()
# Out:
#    cps19_interest_gen_1  cps19_interest_elxn_1   cps19_v_likely  \
# 0                  9.00                   9.00  Certain to vote
# 1                  6.00                   6.00  Certain to vote
# 2                  8.00                   8.00  Certain to vote
# 3                  8.00                   8.00  Certain to vote
# 4                  8.00                   6.00  Certain to vote
#
#                    cps19_votechoice  cps19_vote_unlike_pr_7_TEXT  \
# 0                       Green Party                          NaN
# 1  Don't know/ Prefer not to answer                          NaN
# 2                     Liberal Party                          NaN
# 3                Conservative Party                          NaN
# 4  Don't know/ Prefer not to answer                          NaN
#
#    cps19_vote_lean_pr_7_TEXT                  cps19_2nd_choice  \
# 0                        NaN                     Liberal Party
# ...

# %%
cps_df.drop(['cps19_not_vote_for_6', 'cps19_not_vote_for_7', 'cps19_not_vote_for_8', 'cps19_not_vote_for_9', 'cps19_not_vote_for_7_TEXT'], axis=1, inplace=True)

# %%
cps_df.iloc[:, 10:20].head()
# Out:
#    cps19_interest_gen_1  cps19_interest_elxn_1   cps19_v_likely  \
# 0                  9.00                   9.00  Certain to vote
# 1                  6.00                   6.00  Certain to vote
# 2                  8.00                   8.00  Certain to vote
# 3                  8.00                   8.00  Certain to vote
# 4                  8.00                   6.00  Certain to vote
#
#                    cps19_votechoice  cps19_vote_unlike_pr_7_TEXT  \
# 0                       Green Party                          NaN
# 1  Don't know/ Prefer not to answer                          NaN
# 2                     Liberal Party                          NaN
# 3                Conservative Party                          NaN
# 4  Don't know/ Prefer not to answer                          NaN
#
#    cps19_vote_lean_pr_7_TEXT                  cps19_2nd_choice  \
# 0                        NaN                     Liberal Party
# ...

# %%
cps_df.iloc[:, 30:40].head()
# Out:
#    cps19_cand_rating_23  cps19_cand_rating_24  cps19_cand_rating_25  \
# 0                 58.00                  0.00                 69.00
# 1                   NaN                   NaN                 64.00
# 2                   NaN                   NaN                   NaN
# 3                  0.00                 80.00                  0.00
# 4                   NaN                   NaN                   NaN
#
#    cps19_cand_rating_26  cps19_cand_rating_27  cps19_cand_rating_28  \
# 0                  0.00                 76.00                  0.00
# 1                   NaN                 88.00                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                  0.00                  0.00
# 4                   NaN                   NaN                   NaN
#
#    cps19_lr_scale_bef_1  cps19_lr_parties_1  cps19_lr_parties_2  \
# 0                   NaN                5.00                9.00
# ...

# %%
cps_df['cps19_lr_scale_bef_1'].value_counts().sum()
# Out:
# 14503

# %%
cps_df.iloc[:, 40:50].head()
# Out:
#    cps19_lr_parties_4  cps19_lr_parties_5  cps19_lr_parties_6  \
# 0                5.00                2.00               10.00
# 1                5.00                 NaN                 NaN
# 2                 NaN                4.00                9.00
# 3                5.00                4.00                9.00
# 4                8.00                1.00                7.00
#
#    cps19_lr_scale_aft_1 cps19_lead_int_113 cps19_lead_int_114  \
# 0                  2.00     Justin Trudeau                NaN
# 1                  2.00                NaN                NaN
# 2                   NaN     Justin Trudeau                NaN
# 3                   NaN                NaN      Andrew Scheer
# 4                   NaN                NaN      Andrew Scheer
#
#   cps19_lead_int_115 cps19_lead_int_116 cps19_lead_int_117 cps19_lead_int_118
# 0      Jagmeet Singh                NaN      Elizabeth May                NaN
# ...

# %%
cps_df['cps19_lr_scale_aft_1'].value_counts().sum()
# Out:
# 14833

# %%
cps_df.loc[(cps_df['cps19_lr_scale_bef_1'].isnull()) & (cps_df['cps19_lr_scale_aft_1'].isnull()), ['cps19_lr_scale_bef_1', 'cps19_lr_scale_aft_1']]
# Out:
#        cps19_lr_scale_bef_1  cps19_lr_scale_aft_1
# 30                      NaN                   NaN
# 37                      NaN                   NaN
# 53                      NaN                   NaN
# 75                      NaN                   NaN
# 89                      NaN                   NaN
# ...                     ...                   ...
# 37812                   NaN                   NaN
# 37813                   NaN                   NaN
# 37814                   NaN                   NaN
# 37816                   NaN                   NaN
# 37819                   NaN                   NaN
#
# [8486 rows x 2 columns]

# %%
left_right = cps_df[['cps19_lr_scale_bef_1', 'cps19_lr_scale_aft_1']]
left_right.head()
# Out:
#    cps19_lr_scale_bef_1  cps19_lr_scale_aft_1
# 0                   NaN                  2.00
# 1                   NaN                  2.00
# 2                  4.00                   NaN
# 3                  7.00                   NaN
# 4                  4.00                   NaN

# %%
left_right['cps19_lr_scale_bef_1'][0] = left_right['cps19_lr_scale_aft_1'][0]
left_right.head()
# Out:
#    cps19_lr_scale_bef_1  cps19_lr_scale_aft_1
# 0                  2.00                  2.00
# 1                   NaN                  2.00
# 2                  4.00                   NaN
# 3                  7.00                   NaN
# 4                  4.00                   NaN

# %%
left_right
# Out:
#        cps19_lr_scale_bef_1  cps19_lr_scale_aft_1
# 0                      2.00                  2.00
# 1                       NaN                  2.00
# 2                      4.00                   NaN
# 3                      7.00                   NaN
# 4                      4.00                   NaN
# ...                     ...                   ...
# 37817                   NaN                  2.00
# 37818                  8.00                   NaN
# 37819                   NaN                   NaN
# 37820                  3.00                   NaN
# 37821                   NaN                  6.00
#
# [37822 rows x 2 columns]

# %%
left_right.dropna()
# Out:
#    cps19_lr_scale_bef_1  cps19_lr_scale_aft_1
# 0                  2.00                  2.00

# %%
cps_df.iloc[:, 220:230].head()
# Out:
#    cps19_household
# 0             2.00
# 1             2.00
# 2             5.00
# 3             6.00
# 4             6.00

# %%
cps_df['cps19_sexuality_4_TEXT'].isnull().sum()
# Out:
# 37508

# %%
cps_df.drop('cps19_sexuality_4_TEXT', axis=1, inplace=True)

# %%
cps_df.head()
# Out:
#     cps19_ResponseId cps19_citizenship  cps19_yob cps19_gender cps19_province  \
# 0  R_1OpYXEFGzHRUpjM  Canadian citizen       1989      A woman         Quebec
# 1  R_2qdrL3J618rxYW0  Canadian citizen       1998      A woman         Quebec
# 2  R_USWDAPcQEQiMmNb  Canadian citizen       2000      A woman        Ontario
# 3  R_3IQaeDXy0tBzEry  Canadian citizen       1998        A man        Ontario
# 4  R_27WeMQ1asip2cMD  Canadian citizen       2000      A woman        Ontario
#
#                     cps19_education                      cps19_demsat  \
# 0                   Master's degree                  Fairly satisfied
# 1                   Master's degree  Don't know/ Prefer not to answer
# 2                   Some university                  Fairly satisfied
# 3                   Some university                  Fairly satisfied
# 4  Completed secondary/ high school                  Fairly satisfied
#
#                       cps19_imp_iss               cps19_imp_iss_party  \
# ...

# %%
cps_df['cps19_citizenship'].value_counts()
# Out:
# Canadian citizen      36480
# Permanent resident     1342
# Name: cps19_citizenship, dtype: int64

# %%
cps_df.drop(cps_df[cps_df['cps19_citizenship'] == 'Permanent resident'].index, inplace=True)

# %%
cps_df['cps19_citizenship'].value_counts()
# Out:
# Canadian citizen    36480
# Name: cps19_citizenship, dtype: int64

# %%
cps_df.drop('cps19_imp_loc_iss_p', axis=1, inplace=True)

# %%
cps_df.iloc[:, 0:10].isnull().sum()
# Out:
# cps19_ResponseId           0
# cps19_citizenship          0
# cps19_yob                  0
# cps19_gender               0
# cps19_province             0
# cps19_education            0
# cps19_demsat               0
# cps19_imp_iss           6979
# cps19_imp_iss_party     6963
# cps19_interest_gen_1    2324
# dtype: int64

# %%
cps_df.iloc[:, 10:20].head()
# Out:
#    cps19_interest_elxn_1   cps19_v_likely                  cps19_votechoice  \
# 0                   9.00  Certain to vote                       Green Party
# 1                   6.00  Certain to vote  Don't know/ Prefer not to answer
# 2                   8.00  Certain to vote                     Liberal Party
# 3                   8.00  Certain to vote                Conservative Party
# 4                   6.00  Certain to vote  Don't know/ Prefer not to answer
#
#    cps19_vote_unlike_pr_7_TEXT  cps19_vote_lean_pr_7_TEXT  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
#
#                    cps19_2nd_choice   cps19_fed_gov_sat  \
# 0                     Liberal Party  Not very satisfied
# ...

# %%
cps_df.drop('cps19_vote_unlike_pr_7_TEXT', axis=1, inplace=True)

# %%
cps_df.drop('cps19_vote_lean_pr_7_TEXT', axis=1, inplace=True)

# %%
cps_df.iloc[:, 10:20].head()
# Out:
#    cps19_interest_elxn_1   cps19_v_likely                  cps19_votechoice  \
# 0                   9.00  Certain to vote                       Green Party
# 1                   6.00  Certain to vote  Don't know/ Prefer not to answer
# 2                   8.00  Certain to vote                     Liberal Party
# 3                   8.00  Certain to vote                Conservative Party
# 4                   6.00  Certain to vote  Don't know/ Prefer not to answer
#
#                    cps19_2nd_choice   cps19_fed_gov_sat  \
# 0                     Liberal Party  Not very satisfied
# 1                               ndp  Not very satisfied
# 2                               ndp    Fairly satisfied
# 3  Don't know/ Prefer not to answer  Not very satisfied
# 4  Don't know/ Prefer not to answer  Not very satisfied
#
#    cps19_party_rating_23  cps19_party_rating_24  cps19_party_rating_25  \
# 0                  52.00                   0.00                  64.00
# ...

# %%
cps_df.iloc[:, 20:30].head()
# Out:
#    cps19_party_rating_28  cps19_lead_rating_23  cps19_lead_rating_24  \
# 0                   0.00                 55.00                  0.00
# 1                   0.00                 53.00                  0.00
# 2                    NaN                 74.00                 24.00
# 3                  30.00                  0.00                 80.00
# 4                  20.00                 30.00                 60.00
#
#    cps19_lead_rating_25  cps19_lead_rating_26  cps19_lead_rating_27  \
# 0                 71.00                 15.00                 80.00
# 1                   NaN                 32.00                 59.00
# 2                 63.00                   NaN                 56.00
# 3                  0.00                  0.00                  0.00
# 4                   NaN                 50.00                 60.00
#
#    cps19_lead_rating_28  cps19_cand_rating_23  cps19_cand_rating_24  \
# 0                  0.00                 58.00                  0.00
# ...

# %%
cps_df.iloc[:, 30:40].head()
# Out:
#    cps19_cand_rating_26  cps19_cand_rating_27  cps19_cand_rating_28  \
# 0                  0.00                 76.00                  0.00
# 1                   NaN                 88.00                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                  0.00                  0.00
# 4                   NaN                   NaN                   NaN
#
#    cps19_lr_scale_bef_1  cps19_lr_parties_1  cps19_lr_parties_2  \
# 0                   NaN                5.00                9.00
# 1                   NaN                 NaN                 NaN
# 2                  4.00                3.00                7.00
# 3                  7.00                5.00                7.00
# 4                  4.00                4.00                7.00
#
#    cps19_lr_parties_3  cps19_lr_parties_4  cps19_lr_parties_5  \
# 0                3.00                5.00                2.00
# ...

# %%
cps_df.iloc[:, 40:50].head()
# Out:
#    cps19_lr_scale_aft_1 cps19_lead_int_113 cps19_lead_int_114  \
# 0                  2.00     Justin Trudeau                NaN
# 1                  2.00                NaN                NaN
# 2                   NaN     Justin Trudeau                NaN
# 3                   NaN                NaN      Andrew Scheer
# 4                   NaN                NaN      Andrew Scheer
#
#   cps19_lead_int_115 cps19_lead_int_116 cps19_lead_int_117 cps19_lead_int_118  \
# 0      Jagmeet Singh                NaN      Elizabeth May                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4      Jagmeet Singh                NaN                NaN                NaN
#
#   cps19_lead_int_119                cps19_lead_int_120 cps19_lead_strong_113
# ...

# %%
for ind in cps_df.index:
    if pd.isnull(cps_df['cps19_lr_scale_bef_1'][ind]) and pd.notnull(cps_df['cps19_lr_scale_aft_1'][ind]):
        cps_df['cps19_lr_scale_bef_1'][ind] = cps_df['cps19_lr_scale_aft_1'][ind]

# %%
cps_df.drop('cps19_lr_scale_aft_1', axis=1, inplace=True)

# %%
cps_df.rename(columns = {'cps19_lr_scale_bef_1': 'cps19_lr_scale'}, inplace=True)

# %%
cps_df.iloc[:, 30:40].head()
# Out:
#    cps19_cand_rating_26  cps19_cand_rating_27  cps19_cand_rating_28  \
# 0                  0.00                 76.00                  0.00
# 1                   NaN                 88.00                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                  0.00                  0.00
# 4                   NaN                   NaN                   NaN
#
#    cps19_lr_scale  cps19_lr_parties_1  cps19_lr_parties_2  cps19_lr_parties_3  \
# 0            2.00                5.00                9.00                3.00
# 1            2.00                 NaN                 NaN                 NaN
# 2            4.00                3.00                7.00                4.00
# 3            7.00                5.00                7.00                2.00
# 4            4.00                4.00                7.00                 NaN
#
#    cps19_lr_parties_4  cps19_lr_parties_5  cps19_lr_parties_6
# ...

# %%
cps_df.iloc[:, 50:60].head()
# Out:
#   cps19_lead_strong_115 cps19_lead_strong_116 cps19_lead_strong_117  \
# 0                   NaN                   NaN         Elizabeth May
# 1                   NaN                   NaN                   NaN
# 2         Jagmeet Singh                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4         Jagmeet Singh                   NaN                   NaN
#
#   cps19_lead_strong_118 cps19_lead_strong_119  \
# 0                   NaN                   NaN
# 1                   NaN                   NaN
# 2                   NaN                   NaN
# 3                   NaN                   NaN
# 4                   NaN                   NaN
#
#               cps19_lead_strong_120 cps19_lead_trust_113 cps19_lead_trust_114  \
# 0                               NaN                  NaN                  NaN
# 1  Don't know/ Prefer not to answer                  NaN                  NaN
# ...

# %%
cps_df.iloc[:, 60:70].head()
# Out:
#   cps19_lead_trust_117 cps19_lead_trust_118 cps19_lead_trust_119  \
# 0        Elizabeth May                  NaN                  NaN
# 1                  NaN                  NaN        None of these
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#                cps19_lead_trust_120 cps19_lead_cares_113 cps19_lead_cares_114  \
# 0                               NaN                  NaN                  NaN
# 1                               NaN                  NaN                  NaN
# 2  Don't know/ Prefer not to answer                  NaN                  NaN
# 3                               NaN       Justin Trudeau        Andrew Scheer
# 4  Don't know/ Prefer not to answer                  NaN                  NaN
#
#   cps19_lead_cares_115 cps19_lead_cares_116 cps19_lead_cares_117  \
# ...

# %%
cps_df.shape
# Out:
# (36480, 216)

# %%
cps_df.iloc[:, 70:80].head()
# Out:
#   cps19_lead_cares_119              cps19_lead_cares_120  \
# 0                  NaN  Don't know/ Prefer not to answer
# 1                  NaN                               NaN
# 2                  NaN                               NaN
# 3                  NaN                               NaN
# 4                  NaN                               NaN
#
#                    cps19_spend_educ                   cps19_spend_env  \
# 0  Don't know/ Prefer not to answer  Don't know/ Prefer not to answer
# 1                        Spend more                        Spend more
# 2                        Spend more                        Spend more
# 3       Spend about the same as now       Spend about the same as now
# 4                        Spend more                        Spend more
#
#                cps19_spend_just_law               cps19_spend_defence  \
# 0  Don't know/ Prefer not to answer  Don't know/ Prefer not to answer
# ...

# %%
cps_df[['cps19_spend_educ', 'cps19_spend_env', 'cps19_spend_just_law', 'cps19_spend_defence', 'cps19_spend_imm_min']].isnull().sum()
# Out:
# cps19_spend_educ        0
# cps19_spend_env         0
# cps19_spend_just_law    0
# cps19_spend_defence     0
# cps19_spend_imm_min     0
# dtype: int64

# %%
cps_df[['cps19_pos_fptp', 'cps19_pos_life', 'cps19_pos_cannabis']].isnull().sum()
# Out:
# cps19_pos_fptp        24313
# cps19_pos_life        24294
# cps19_pos_cannabis    24517
# dtype: int64

# %%
cps_df.iloc[:, 80:90].head()
# Out:
#     cps19_pos_carbon cps19_pos_energy cps19_pos_envreg     cps19_pos_jobs  \
# 0     Strongly agree              NaN   Strongly agree  Strongly disagree
# 1                NaN              NaN   Strongly agree                NaN
# 2  Somewhat disagree              NaN              NaN     Somewhat agree
# 3                NaN              NaN              NaN                NaN
# 4                NaN   Strongly agree              NaN                NaN
#
#   cps19_pos_subsid cps19_pos_trade                  cps19_econ_retro  \
# 0              NaN             NaN             Stayed about the same
# 1   Somewhat agree             NaN             Stayed about the same
# 2              NaN             NaN  Don't know/ Prefer not to answer
# 3              NaN  Somewhat agree                         Got worse
# 4              NaN             NaN                         Got worse
#
#                      cps19_econ_fed               cps19_ownfinanc_fed  \
# ...

# %%
cps_df.drop(['cps19_pos_carbon', 'cps19_pos_energy', 'cps19_pos_envreg', 'cps19_pos_jobs', 'cps19_pos_subsid', 'cps19_pos_trade'], axis=1, inplace=True)

# %%
cps_df[['cps19_econ_retro', 'cps19_econ_fed', 'cps19_ownfinanc_fed']].isnull().sum()
# Out:
# cps19_econ_retro       0
# cps19_econ_fed         0
# cps19_ownfinanc_fed    0
# dtype: int64

# %%
cps_df.iloc[:, 80:90].head()
# Out:
#                    cps19_econ_retro                    cps19_econ_fed  \
# 0             Stayed about the same  Don't know/ Prefer not to answer
# 1             Stayed about the same          Not made much difference
# 2  Don't know/ Prefer not to answer                             Worse
# 3                         Got worse                             Worse
# 4                         Got worse  Don't know/ Prefer not to answer
#
#                 cps19_ownfinanc_fed cps19_issue_handle_1 cps19_issue_handle_2  \
# 0  Don't know/ Prefer not to answer                  NaN                  NaN
# 1          Not made much difference                  NaN                  NaN
# 2          Not made much difference                  NaN                  NaN
# 3          Not made much difference                  NaN                  NaN
# 4                             Worse                  NaN                  NaN
#
#   cps19_issue_handle_3 cps19_issue_handle_4 cps19_issue_handle_5  \
# ...

# %%
cps_df.drop(['cps19_issue_handle_1', 'cps19_issue_handle_2', 'cps19_issue_handle_3', 'cps19_issue_handle_4', 'cps19_issue_handle_5'], axis=1, inplace=True)

# %%
cps_df.iloc[:, 80:90].head()
# Out:
#                    cps19_econ_retro                    cps19_econ_fed  \
# 0             Stayed about the same  Don't know/ Prefer not to answer
# 1             Stayed about the same          Not made much difference
# 2  Don't know/ Prefer not to answer                             Worse
# 3                         Got worse                             Worse
# 4                         Got worse  Don't know/ Prefer not to answer
#
#                 cps19_ownfinanc_fed cps19_issue_handle_6 cps19_issue_handle_7  \
# 0  Don't know/ Prefer not to answer                  NaN                  NaN
# 1          Not made much difference                  NaN                  NaN
# 2          Not made much difference                  NaN                  NaN
# 3          Not made much difference                  NaN                  NaN
# 4                             Worse                  NaN                  NaN
#
#   cps19_issue_handle_8  cps19_most_seats_1  cps19_most_seats_2  \
# ...

# %%
cps_df.drop(['cps19_issue_handle_6', 'cps19_issue_handle_7', 'cps19_issue_handle_8', 'cps19_most_seats_1', 
            'cps19_most_seats_2', 'cps19_most_seats_3', 'cps19_most_seats_4'], axis=1, inplace=True)

# %%
cps_df.iloc[:, 80:90].head()
# Out:
#                    cps19_econ_retro                    cps19_econ_fed  \
# 0             Stayed about the same  Don't know/ Prefer not to answer
# 1             Stayed about the same          Not made much difference
# 2  Don't know/ Prefer not to answer                             Worse
# 3                         Got worse                             Worse
# 4                         Got worse  Don't know/ Prefer not to answer
#
#                 cps19_ownfinanc_fed  cps19_most_seats_5  cps19_most_seats_6  \
# 0  Don't know/ Prefer not to answer               50.00                0.00
# 1          Not made much difference               55.00                 NaN
# 2          Not made much difference               32.00               45.00
# 3          Not made much difference                0.00                0.00
# 4                             Worse                0.00               20.00
#
#    cps19_win_local_1  cps19_win_local_2  cps19_win_local_3  cps19_win_local_4  \
# ...

# %%
cps_df.drop(['cps19_most_seats_5', 'cps19_most_seats_6', 'cps19_win_local_1', 'cps19_win_local_2', 'cps19_win_local_3',
            'cps19_win_local_4', 'cps19_win_local_5'], axis=1, inplace=True)

# %%
cps_df.iloc[:, 80:90].head()
# Out:
#                    cps19_econ_retro                    cps19_econ_fed  \
# 0             Stayed about the same  Don't know/ Prefer not to answer
# 1             Stayed about the same          Not made much difference
# 2  Don't know/ Prefer not to answer                             Worse
# 3                         Got worse                             Worse
# 4                         Got worse  Don't know/ Prefer not to answer
#
#                 cps19_ownfinanc_fed  cps19_win_local_6     cps19_outcome_most  \
# 0  Don't know/ Prefer not to answer                NaN                    NaN
# 1          Not made much difference                NaN       Liberal minority
# 2          Not made much difference                NaN                    NaN
# 3          Not made much difference              30.00  Conservative majority
# 4                             Worse               0.00                    NaN
#
#   cps19_outcome_most_14_TEXT    cps19_outcome_least  \
# ...

# %%
cps_df.drop(['cps19_win_local_6', 'cps19_outcome_most', 'cps19_outcome_most_14_TEXT', 'cps19_outcome_least', 'cps19_outcome_least_14_TEXT'], axis=1, inplace=True)

# %%
cps_df['cps19_imm'].isnull().sum()
# Out:
# 0

# %%
cps_df.iloc[:, 80:90].head()
# Out:
#                    cps19_econ_retro                    cps19_econ_fed  \
# 0             Stayed about the same  Don't know/ Prefer not to answer
# 1             Stayed about the same          Not made much difference
# 2  Don't know/ Prefer not to answer                             Worse
# 3                         Got worse                             Worse
# 4                         Got worse  Don't know/ Prefer not to answer
#
#                 cps19_ownfinanc_fed  \
# 0  Don't know/ Prefer not to answer
# 1          Not made much difference
# 2          Not made much difference
# 3          Not made much difference
# 4                             Worse
#
#                                     cps19_imm  \
# 0                             More immigrants
# 1  About the same number of immigrants as now
# 2  About the same number of immigrants as now
# 3  About the same number of immigrants as now
# 4                             More immigrants
#
# ...

# %%
cps_df[['cps19_refugees', 'cps19_govt_confusing', 'cps19_govt_say', 'cps19_pol_eth', 'cps19_lib_promises', 'cps19_snclav']].isnull().sum()
# Out:
# cps19_refugees          0
# cps19_govt_confusing    0
# cps19_govt_say          0
# cps19_pol_eth           0
# cps19_lib_promises      0
# cps19_snclav            0
# dtype: int64

# %%
cps_df.iloc[:, 90:100].head()
# Out:
#   cps19_news_cons                   cps19_volunteer  \
# 0             NaN  Don't know/ Prefer not to answer
# 1             NaN                       A few times
# 2             NaN                       A few times
# 3             NaN  Don't know/ Prefer not to answer
# 4    1-10 minutes              More than five times
#
#                   cps19_duty_choice                  cps19_quebec_sov  \
# 0  Don't know/ Prefer not to answer  Don't know/ Prefer not to answer
# 1                              Duty  Don't know/ Prefer not to answer
# 2                              Duty                               NaN
# 3                              Duty                               NaN
# 4                              Duty                               NaN
#
#                 cps19_own_fin_retro cps19_premier_name cps19_finmin_name  \
# 0  Don't know/ Prefer not to answer            Legault               NaN
# 1             Stayed about the same            legault           Morneau
# ...

# %%
cps_df['cps19_news_cons'].isnull().sum()
# Out:
# 18417

# %%
cps_df.iloc[:, 90:100].isnull().sum()
# Out:
# cps19_news_cons        18417
# cps19_volunteer            0
# cps19_duty_choice          0
# cps19_quebec_sov       28284
# cps19_own_fin_retro        0
# cps19_premier_name      8072
# cps19_finmin_name      24736
# cps19_govgen_name      29217
# cps19_presrus_name     22502
# cps19_prov_gov_sat         0
# dtype: int64

# %%
cps_df.drop(['cps19_news_cons', 'cps19_quebec_sov', 'cps19_premier_name', 'cps19_finmin_name', 'cps19_govgen_name',
            'cps19_presrus_name'], axis=1, inplace=True)

# %%
cps_df.iloc[:, 90:100].head()
# Out:
#                     cps19_volunteer                 cps19_duty_choice  \
# 0  Don't know/ Prefer not to answer  Don't know/ Prefer not to answer
# 1                       A few times                              Duty
# 2                       A few times                              Duty
# 3  Don't know/ Prefer not to answer                              Duty
# 4              More than five times                              Duty
#
#                 cps19_own_fin_retro    cps19_prov_gov_sat  \
# 0  Don't know/ Prefer not to answer  Not at all satisfied
# 1             Stayed about the same  Not at all satisfied
# 2             Stayed about the same    Not very satisfied
# 3             Stayed about the same      Fairly satisfied
# 4                         Got worse      Fairly satisfied
#
#                        cps19_fed_id cps19_fed_id_7_TEXT  \
# 0  Don't know/ Prefer not to answer                 NaN
# 1                             Green                 NaN
# ...

# %%
cps_df.drop(['cps19_fed_id', 'cps19_fed_id_7_TEXT', 'cps19_fed_id_str', 'cps19_prov_id', 'cps19_prov_id_295_TEXT',
            'cps19_prov_id_str'], axis=1, inplace=True)

# %%
cps_df.iloc[:, 90:100].head()
# Out:
#                     cps19_volunteer                 cps19_duty_choice  \
# 0  Don't know/ Prefer not to answer  Don't know/ Prefer not to answer
# 1                       A few times                              Duty
# 2                       A few times                              Duty
# 3  Don't know/ Prefer not to answer                              Duty
# 4              More than five times                              Duty
#
#                 cps19_own_fin_retro    cps19_prov_gov_sat  \
# 0  Don't know/ Prefer not to answer  Not at all satisfied
# 1             Stayed about the same  Not at all satisfied
# 2             Stayed about the same    Not very satisfied
# 3             Stayed about the same      Fairly satisfied
# 4                         Got worse      Fairly satisfied
#
#                                cps19_party_member_36 cps19_party_member_37  \
# 0                                                NaN                   NaN
# ...

# %%
cps_df.drop(['cps19_party_member_36', 'cps19_party_member_37', 'cps19_party_member_38', 'cps19_party_member_39',
            'cps19_party_member_40', 'cps19_fed_member'], axis=1, inplace=True)

# %%
cps_df.iloc[:, 90:100].head()
# Out:
#                     cps19_volunteer                 cps19_duty_choice  \
# 0  Don't know/ Prefer not to answer  Don't know/ Prefer not to answer
# 1                       A few times                              Duty
# 2                       A few times                              Duty
# 3  Don't know/ Prefer not to answer                              Duty
# 4              More than five times                              Duty
#
#                 cps19_own_fin_retro    cps19_prov_gov_sat  \
# 0  Don't know/ Prefer not to answer  Not at all satisfied
# 1             Stayed about the same  Not at all satisfied
# 2             Stayed about the same    Not very satisfied
# 3             Stayed about the same      Fairly satisfied
# 4                         Got worse      Fairly satisfied
#
#   cps19_fed_member_62_TEXT cps19_prov_member cps19_prov_member_295_TEXT  \
# 0                      NaN               NaN                        NaN
# ...

# %%
cps_df.drop(['cps19_fed_member_62_TEXT', 'cps19_prov_member', 'cps19_prov_member_295_TEXT', 'cps19_fed_donate'], axis=1, inplace=True)

# %%
cps_df['cps19_groups_therm_1'].isnull().sum()
# Out:
# 6484

# %%
cps_df.iloc[:, 90:100].isnull().sum()
# Out:
# cps19_volunteer             0
# cps19_duty_choice           0
# cps19_own_fin_retro         0
# cps19_prov_gov_sat          0
# cps19_groups_therm_1     6484
# cps19_groups_therm_2     6057
# cps19_groups_therm_3     6558
# cps19_groups_therm_4     5960
# cps19_groups_therm_5     5603
# cps19_spoil             10056
# dtype: int64

# %%
cps_df.drop('cps19_spoil', axis=1, inplace=True)

# %%
cps_df.iloc[:, 90:100].isnull().sum()
# Out:
# cps19_volunteer            0
# cps19_duty_choice          0
# cps19_own_fin_retro        0
# cps19_prov_gov_sat         0
# cps19_groups_therm_1    6484
# cps19_groups_therm_2    6057
# cps19_groups_therm_3    6558
# cps19_groups_therm_4    5960
# cps19_groups_therm_5    5603
# cps19_turnout_2015         0
# dtype: int64

# %%
cps_df.iloc[:, 100:110].isnull().sum()
# Out:
# cps19_vote_2015            6536
# cps19_vote_2015_6_TEXT    36342
# cps19_debate_en           21767
# cps19_debate_fr           23970
# cps19_religion                0
# cps19_religion_22_TEXT    35295
# cps19_rel_imp              9591
# cps19_bornin_canada           0
# cps19_bornin_other        31555
# cps19_imm_year            31555
# dtype: int64

# %%
cps_df.drop(['cps19_vote_2015_6_TEXT', 'cps19_debate_en', 'cps19_debate_fr', 'cps19_religion_22_TEXT', 'cps19_rel_imp',
            'cps19_bornin_other', 'cps19_imm_year'], axis=1, inplace=True)

# %%
cps_df.iloc[:, 100:110].head()
# Out:
#   cps19_vote_2015                    cps19_religion  \
# 0             NaN  Don't know/ Prefer not to answer
# 1     Green Party      Catholic/ Roman Catholic/ RC
# 2             NaN      Catholic/ Roman Catholic/ RC
# 3             NaN  Jewish/ Judaism/ Jewish Orthodox
# 4             NaN      Catholic/ Roman Catholic/ RC
#
#              cps19_bornin_canada cps19_ethnicity_23 cps19_ethnicity_24  \
# 0  Don't know/ Prefer not to say                NaN                NaN
# 1                            Yes                NaN                NaN
# 2                            Yes                NaN                NaN
# 3                            Yes                NaN            British
# 4                            Yes                NaN                NaN
#
#   cps19_ethnicity_25 cps19_ethnicity_26 cps19_ethnicity_27 cps19_ethnicity_28  \
# 0                NaN                NaN                NaN                NaN
# ...

# %%
cps_df['cps19_ethnicity_23'].fillna('No', inplace=True)

# %%
cps_df['cps19_ethnicity_23'].value_counts()
# Out:
# No                           34791
# Aboriginal/ First Nations     1689
# Name: cps19_ethnicity_23, dtype: int64

# %%
cps_df.rename(columns = {
    'cps19_ethnicity_23': 'cps19_ethnicity_first_nat',
    'cps19_ethnicity_24': 'cps19_ethnicity_british',
    'cps19_ethnicity_25': 'cps19_ethnicity_chinese',
    }, inplace=True)

# %%
cps_df.rename(columns = {
    'cps19_ethnicity_26': 'cps19_ethnicity_dutch',
    'cps19_ethnicity_27': 'cps19_ethnicity_english',
    'cps19_ethnicity_29': 'cps19_ethnicity_french_can',
    'cps19_ethnicity_30': 'cps19_ethnicity_german',
    'cps19_ethnicity_31': 'cps19_ethnicity_hispanic',
    'cps19_ethnicity_32': 'cps19_ethnicity_indian',
    'cps19_ethnicity_33': 'cps19_ethnicity_inuk_inuit',
    'cps19_ethnicity_34': 'cps19_ethnicity_irish',
    'cps19_ethnicity_35': 'cps19_ethnicity_italian',
    'cps19_ethnicity_36': 'cps19_ethnicity_metis',
    'cps19_ethnicity_37': 'cps19_ethnicity_polish',
    'cps19_ethnicity_38': 'cps19_ethnicity_quebecois',
    'cps19_ethnicity_39': 'cps19_ethnicity_scottish',
    'cps19_ethnicity_40': 'cps19_ethnicity_ukranian',
    'cps19_ethnicity_41': 'cps19_ethnicity_other1',
    'cps19_ethnicity_42': 'cps19_ethnicity_other2'
    }, inplace=True)

# %%
cps_df.iloc[:, 100:110].head()
# Out:
#   cps19_vote_2015                    cps19_religion  \
# 0             NaN  Don't know/ Prefer not to answer
# 1     Green Party      Catholic/ Roman Catholic/ RC
# 2             NaN      Catholic/ Roman Catholic/ RC
# 3             NaN  Jewish/ Judaism/ Jewish Orthodox
# 4             NaN      Catholic/ Roman Catholic/ RC
#
#              cps19_bornin_canada cps19_ethnicity_first_nat  \
# 0  Don't know/ Prefer not to say                        No
# 1                            Yes                        No
# 2                            Yes                        No
# 3                            Yes                        No
# 4                            Yes                        No
#
#   cps19_ethnicity_british cps19_ethnicity_chinese cps19_ethnicity_dutch  \
# 0                      No                      No                    No
# 1                      No                      No                    No
# 2                      No                      No                    No
# ...

# %%
for column in cps_df.columns:
    if 'ethnicity' in column:
        cps_df[column].fillna('No', inplace=True)

# %%
cps_df.iloc[:, 110:120].head()
# Out:
#   cps19_ethnicity_german cps19_ethnicity_hispanic cps19_ethnicity_indian  \
# 0                     No                       No                     No
# 1                     No                       No                     No
# 2                     No                       No                     No
# 3                     No                       No                     No
# 4                     No                       No                     No
#
#   cps19_ethnicity_inuk_inuit cps19_ethnicity_irish cps19_ethnicity_italian  \
# 0                         No                    No                      No
# 1                         No                 Irish                      No
# 2                         No                    No                 Italian
# 3                         No                    No                 Italian
# 4                         No                    No                      No
#
#   cps19_ethnicity_metis cps19_ethnicity_polish cps19_ethnicity_quebecois  \
# ...

# %%
cps_df.iloc[:, 120:130].head()
# Out:
#   cps19_ethnicity_ukranian    cps19_ethnicity_other1 cps19_ethnicity_other2  \
# 0                       No                        No                     No
# 1                       No                        No                     No
# 2                       No                        No                     No
# 3                       No                        No                     No
# 4                       No  Other 1 (please specify)                     No
#
#   cps19_ethnicity_43 cps19_ethnicity_41_TEXT cps19_ethnicity_42_TEXT  \
# 0                 No                      No                      No
# 1                 No                      No                      No
# 2                 No                      No                      No
# 3                 No                      No                      No
# 4                 No                Filipino                      No
#
#      cps19_sexuality cps19_language_68 cps19_language_69 cps19_language_70
# ...

# %%
cps_df.drop(['cps19_ethnicity_other1', 'cps19_ethnicity_other2'], axis=1, inplace=True)

# %%
cps_df.rename(columns= {'cps19_ethnicity_43': 'cps19_ethnicity_no_answer'}, inplace=True)b

# %%
for column in cps_df.columns:
    if 'language' in column:
        print(column)
# Out:
# cps19_language_68
# cps19_language_69
# cps19_language_70
# cps19_language_71
# cps19_language_72
# cps19_language_73
# cps19_language_74
# cps19_language_75
# cps19_language_76
# cps19_language_77
# cps19_language_78
# cps19_language_79
# cps19_language_80
# cps19_language_81
# cps19_language_82
# cps19_language_83
# cps19_language_84
# cps19_language_85
# cps19_language_70_TEXT
# cps19_language_84_TEXT

# %%
cps_df.rename(columns = {
    'cps19_language_68': 'cps19_language_english',
    'cps19_language_69': 'cps19_language_french',
    'cps19_language_70_TEXT': 'cps19_language_aborginal',
    'cps19_language_71': 'cps19_language_arabic',
    'cps19_language_72': 'cps19_languague_chinese',
    'cps19_language_73': 'cps19_language_filipino',
    'cps19_language_74': 'cps19_language_german',
    'cps19_language_75': 'cps19_language_indian',
    'cps19_language_76': 'cps19_language_italian',
    'cps19_language_77': 'cps19_language_korean',
    'cps19_language_78': 'cps19_language_pakistani',
    'cps19_language_79': 'cps19_language_persian',
    'cps19_language_80': 'cps19_language_russian',
    'cps19_language_81': 'cps19_language_spanish',
    'cps19_language_82': 'cps19_language_tamil',
    'cps19_language_83': 'cps19_language_vietnamese',
    'cps19_language_84_TEXT': 'cps_19_language_other'
}, inplace=True)

# %%
for column in cps_df.columns:
    if 'language' in column:
        cps_df[column].fillna('No', inplace=True)

# %%
cps_df.drop(['cps19_language_70', 'cps19_language_84'], axis=1, inplace=True)

# %%
cps_df.rename({'cps19_language_85': 'cps19_language_no_answer'}, axis=1, inplace=True)

# %%
cps_df.iloc[:, 140:150].isnull().sum()
# Out:
# cps19_language_no_answer        0
# cps19_language_aborginal        0
# cps_19_language_other           0
# cps19_employment                0
# cps19_employment_12_TEXT    36061
# cps19_sector                17738
# cps19_union                     0
# cps19_children                  0
# cps19_income_number         11719
# cps19_property_6            35078
# dtype: int64

# %%
cps_df['cps19_employment'].value_counts()
# Out:
# Working for pay full-time                    15520
# Retired                                       8909
# Working for pay part-time                     3222
# Self employed (with or without employees)     2446
# Unemployed/ looking for work                  1558
# Disabled                                      1279
# Student                                       1222
# Caring for a family                           1010
# Other (please specify)                         419
# Retired and working for pay                    316
# Don't know/ Prefer not to answer               299
# Student and working for pay                    163
# Caring for family and working for pay          117
# Name: cps19_employment, dtype: int64

# %%
cps_df.drop('cps19_employment_12_TEXT', axis=1, inplace=True)

# %%
cps_df.drop('cps19_sector', axis=1, inplace=True)

# %%
cps_df.drop('cps19_property_6', axis=1, inplace=True)

# %%
cps_df.shape
# Out:
# (36480, 149)

# %%
cps_df.isnull().sum()
# Out:
# cps19_ResponseId           0
# cps19_citizenship          0
# cps19_yob                  0
# cps19_gender               0
# cps19_province             0
#                        ...
# cps19_union                0
# cps19_children             0
# cps19_income_number    11719
# cps19_marital              0
# cps19_household         1785
# Length: 149, dtype: int64

# %%
lead_col = []
for column in cps_df.columns:
    if 'lead' in column:
        lead_col.append(column)
cps_df[lead_col].head()
# Out:
#    cps19_lead_rating_23  cps19_lead_rating_24  cps19_lead_rating_25  \
# 0                 55.00                  0.00                 71.00
# 1                 53.00                  0.00                   NaN
# 2                 74.00                 24.00                 63.00
# 3                  0.00                 80.00                  0.00
# 4                 30.00                 60.00                   NaN
#
#    cps19_lead_rating_26  cps19_lead_rating_27  cps19_lead_rating_28  \
# 0                 15.00                 80.00                  0.00
# 1                 32.00                 59.00                  0.00
# 2                   NaN                 56.00                 20.00
# 3                  0.00                  0.00                 10.00
# 4                 50.00                 60.00                 30.00
#
#   cps19_lead_int_113 cps19_lead_int_114 cps19_lead_int_115 cps19_lead_int_116  \
# ...

# %%
cps_df.drop(lead_col, axis=1, inplace=True)

# %%
cps_df.isnull().sum()
# Out:
# cps19_ResponseId           0
# cps19_citizenship          0
# cps19_yob                  0
# cps19_gender               0
# cps19_province             0
#                        ...
# cps19_union                0
# cps19_children             0
# cps19_income_number    11719
# cps19_marital              0
# cps19_household         1785
# Length: 111, dtype: int64

# %%
cps_df.iloc[:, 0:20].isnull().sum()
# Out:
# cps19_ResponseId            0
# cps19_citizenship           0
# cps19_yob                   0
# cps19_gender                0
# cps19_province              0
# cps19_education             0
# cps19_demsat                0
# cps19_imp_iss            6979
# cps19_imp_iss_party      6963
# cps19_interest_gen_1     2324
# cps19_interest_elxn_1    2195
# cps19_v_likely              0
# cps19_votechoice         4916
# cps19_2nd_choice         6100
# cps19_fed_gov_sat           0
# cps19_party_rating_23    2515
# cps19_party_rating_24    2644
# cps19_party_rating_25    3646
# cps19_party_rating_26    3626
# cps19_party_rating_27    4440
# dtype: int64

# %%
cps_df.drop('cps19_2nd_choice', axis=1, inplace=True)

# %%
cps_df.iloc[:, 20:40].isnull().sum()
# Out:
# cps19_party_rating_28     4823
# cps19_cand_rating_23      8183
# cps19_cand_rating_24      8361
# cps19_cand_rating_25      9746
# cps19_cand_rating_26     30337
# cps19_cand_rating_27     10519
# cps19_cand_rating_28     10290
# cps19_lr_scale            8249
# cps19_lr_parties_1        9771
# cps19_lr_parties_2        9288
# cps19_lr_parties_3       10080
# cps19_lr_parties_4       11908
# cps19_lr_parties_5       10779
# cps19_lr_parties_6       11593
# cps19_spend_educ             0
# cps19_spend_env              0
# cps19_spend_just_law         0
# cps19_spend_defence          0
# cps19_spend_imm_min          0
# cps19_pos_fptp           24313
# dtype: int64

# %%
cps_df.iloc[:, 40:60].isnull().sum()
# Out:
# cps19_pos_life          24294
# cps19_pos_cannabis      24517
# cps19_econ_retro            0
# cps19_econ_fed              0
# cps19_ownfinanc_fed         0
# cps19_imm                   0
# cps19_refugees              0
# cps19_govt_confusing        0
# cps19_govt_say              0
# cps19_pol_eth               0
# cps19_lib_promises          0
# cps19_snclav                0
# cps19_volunteer             0
# cps19_duty_choice           0
# cps19_own_fin_retro         0
# cps19_prov_gov_sat          0
# cps19_groups_therm_1     6484
# cps19_groups_therm_2     6057
# cps19_groups_therm_3     6558
# cps19_groups_therm_4     5960
# dtype: int64

# %%
cps_df.iloc[:, 60:80].isnull().sum()
# Out:
# cps19_groups_therm_5          5603
# cps19_turnout_2015               0
# cps19_vote_2015               6536
# cps19_religion                   0
# cps19_bornin_canada              0
# cps19_ethnicity_first_nat        0
# cps19_ethnicity_british          0
# cps19_ethnicity_chinese          0
# cps19_ethnicity_dutch            0
# cps19_ethnicity_english          0
# cps19_ethnicity_28               0
# cps19_ethnicity_french_can       0
# cps19_ethnicity_german           0
# cps19_ethnicity_hispanic         0
# cps19_ethnicity_indian           0
# cps19_ethnicity_inuk_inuit       0
# cps19_ethnicity_irish            0
# cps19_ethnicity_italian          0
# cps19_ethnicity_metis            0
# cps19_ethnicity_polish           0
# dtype: int64

# %%
cps_df.drop('cps19_vote_2015', axis=1, inplace=True)

# %%
cps_df.iloc[:, 80:100].isnull().sum()
# Out:
# cps19_ethnicity_quebecois    0
# cps19_ethnicity_scottish     0
# cps19_ethnicity_ukranian     0
# cps19_ethnicity_no_answer    0
# cps19_ethnicity_41_TEXT      0
# cps19_ethnicity_42_TEXT      0
# cps19_sexuality              0
# cps19_language_english       0
# cps19_language_french        0
# cps19_language_arabic        0
# cps19_language_chinese       0
# cps19_language_filipino      0
# cps19_language_german        0
# cps19_language_indian        0
# cps19_language_italian       0
# cps19_language_korean        0
# cps19_language_pakistani     0
# cps19_language_persian       0
# cps19_language_russian       0
# cps19_language_spanish       0
# dtype: int64

# %%
cps_df.rename({'cps19_languague_chinese' : 'cps19_language_chinese'}, axis=1, inplace=True)

# %%
cps_df['cps19_language_chinese'].fillna('No', inplace=True)

# %%
cps_df.iloc[:, 100:120].isnull().sum()
# Out:
# cps19_language_tamil             0
# cps19_language_vietnamese        0
# cps19_language_no_answer         0
# cps19_language_aborginal         0
# cps_19_language_other            0
# cps19_employment                 0
# cps19_union                      0
# cps19_children                   0
# cps19_income_number          11719
# cps19_marital                    0
# cps19_household               1785
# dtype: int64

# %%
def drop_col(name):
    for column in cps_df:
        if name in column:
            cps_df.drop(column, axis=1, inplace=True)

# %%
drop_col('party_rating')

# %%
drop_col('cand_rating')

# %%
drop_col('lr_parties')

# %%
drop_col('pos')

# %%
cps_df.shape
# Out:
# (36480, 88)

# %%
clean_df = cps_df

# %%
clean_df.shape
# Out:
# (36480, 88)

# %%
clean_df.drop(['cps19_imp_iss', 'cps19_imp_iss_party'], axis=1, inplace=True)

# %%
clean_df.dropna(inplace=True)

# %%
clean_df['cps19_income_number'].describe()
# Out:
# count             13234.00
# mean        75563783223.68
# std       8692694853235.17
# min                   0.00
# 25%               45000.00
# 50%               75000.00
# 75%              110000.00
# max     999999999999999.00
# Name: cps19_income_number, dtype: float64

# %%
import seaborn as sns
sns.boxplot(x=clean_df['cps19_income_number'])
# Out:
# <AxesSubplot:xlabel='cps19_income_number'>

# %%
income_df = clean_df[['cps19_ResponseId','cps19_income_number']]
income_df.head()
# Out:
#      cps19_ResponseId  cps19_income_number
# 4   R_27WeMQ1asip2cMD             56000.00
# 13  R_3j7fAVYfVCewi3H             30000.00
# 20  R_brdMqsPTvQ5t1tL             13000.00
# 21  R_Wumhl7QEMURFqZH             55000.00
# 26  R_3EH051N9vLmOOHM            190000.00

# %%
income_df.sort_values(by='cps19_income_number', ascending=False).head(20)
# Out:
#         cps19_ResponseId  cps19_income_number
# 6773   R_9H87CY80VYRWkbD   999999999999999.00
# 24898  R_1obxzZJmN9OSBlT        8889898989.00
# 10793  R_2fIrutdsPOSdNmX         678876545.00
# 21124  R_12DC7OTEwJAxoPT         300000000.00
# 17275  R_3HTTz7QiSpQtgnw          30000000.00
# 14043  R_2Tt3gl3AC0Wjx8G           9999999.00
# 5407   R_1nSDvwpNdl3qFUw           7696588.00
# 21543  R_2zN1lYqcLc57yuY           7440000.00
# 3698   R_2y4690CBf61WkEs           6848382.00
# 22925  R_UtP29VdHdvQM8Yp           6782800.00
# 16761  R_3fiTYbdlzjua3xo           6500100.00
# 24933  R_3gNmciaqCzbQzyl           2332100.00
# 639    R_2ts2dUPpRRv7QVQ           2000000.00
# 8704   R_VIMLJWyIJruNig1           1650000.00
# 1419   R_rpVOj3PRLbNNyTv           1500000.00
# 16740  R_2ScUxaJXMVFOBmN           1500000.00
# 14060  R_2330Ym3TRUfYXSB           1450000.00
# 12527  R_b9kyogueBWELNYd           1300000.00
# 33857  R_30cQtLe1yszZkdP           1290000.00
# ...

# %%
income_df.drop(6773, inplace=True)

# %%
income_df.describe()
# Out:
#        cps19_income_number
# count             13233.00
# mean             839354.80
# std            77548056.77
# min                   0.00
# 25%               45000.00
# 50%               75000.00
# 75%              110000.00
# max          8889898989.00

# %%
income_df.drop(income_df[income_df['cps19_income_number'] > 5000000].index, inplace=True)

# %%
income_df.sort_values(by='cps19_income_number', ascending=False).head(20)
# Out:
#         cps19_ResponseId  cps19_income_number
# 17275  R_3HTTz7QiSpQtgnw          30000000.00
# 14043  R_2Tt3gl3AC0Wjx8G           9999999.00
# 5407   R_1nSDvwpNdl3qFUw           7696588.00
# 21543  R_2zN1lYqcLc57yuY           7440000.00
# 3698   R_2y4690CBf61WkEs           6848382.00
# 22925  R_UtP29VdHdvQM8Yp           6782800.00
# 16761  R_3fiTYbdlzjua3xo           6500100.00
# 24933  R_3gNmciaqCzbQzyl           2332100.00
# 639    R_2ts2dUPpRRv7QVQ           2000000.00
# 8704   R_VIMLJWyIJruNig1           1650000.00
# 16740  R_2ScUxaJXMVFOBmN           1500000.00
# 1419   R_rpVOj3PRLbNNyTv           1500000.00
# 14060  R_2330Ym3TRUfYXSB           1450000.00
# 12527  R_b9kyogueBWELNYd           1300000.00
# 33857  R_30cQtLe1yszZkdP           1290000.00
# 13260  R_1OgAye8ujvZqHQZ           1250000.00
# 1797   R_2h1iqhQ4kKmQIUx           1000000.00
# 11738  R_1PcsboLQcaJgqnR           1000000.00
# 7792   R_b1KD8f8n1EpMilP           1000000.00
# ...

# %%
income_df.describe()
# Out:
#        cps19_income_number
# count             13223.00
# mean              87963.30
# std               80869.04
# min                   0.00
# 25%               45000.00
# 50%               75000.00
# 75%              110000.00
# max             2332100.00

# %%
sns.boxplot(x=income_df['cps19_income_number'])
# Out:
# <AxesSubplot:xlabel='cps19_income_number'>

# %%
clean_df.drop(clean_df[clean_df['cps19_income_number'] >= 9999999].index, inplace=True)

# %%
sns.boxplot(x=clean_df['cps19_income_number'])
# Out:
# <AxesSubplot:xlabel='cps19_income_number'>
